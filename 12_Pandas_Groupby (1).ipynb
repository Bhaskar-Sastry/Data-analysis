# %% [markdown]
# # **Groupby():**
#
# Group DataFrame using a mapper or by a Series of columns.
#
# groupby operation involves some combination of splitting the object, applying a function, and combining the results. This can be used to group large amounts of data and compute operations on these groups.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Importing required Libraries
import pandas as pd
import numpy as np

# %%
# Read the data from csv file
df=pd.read_csv("tips.csv")
df.shape
# Out:
# (244, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.rename(columns={"total_bill":"bill","sex":"gender"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bill              244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df["gender"].value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
# groupby() single variable.
df.groupby("gender").count()
# Out:
#         bill  tip  smoker  day  time  size  price_per_person  Payer Name  \
# gender
# Female    87   87      87   87    87    87                87          87
# Male     157  157     157  157   157   157               157         157
#
#         CC Number  Payment ID
# gender
# Female         87          87
# Male          157         157

# %%
# Accwssing specific group (Female)
g=df.groupby("gender")
df_female=g.get_group("Female")
df_female.shape
# Out:
# (87, 11)

# %%
df_female.head()
# Out:
#      bill   tip  gender smoker  day    time  size  price_per_person  \
# 0   16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 4   24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 11  35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 14  14.83  3.02  Female     No  Sun  Dinner     2              7.42
# 16  10.33  1.67  Female     No  Sun  Dinner     3              3.44
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 4         Tonya Carter  4832732618637221    Sun2251
# 11        Diane Macias  4577817359320969    Sun6686
# 14       Vanessa Jones    30016702287574    Sun3848
# 16    Elizabeth Foster  4240025044626033    Sun9715

# %%
# Let us access the male group
g.get_group("Male")
# Out:
#       bill   tip gender smoker  day    time  size  price_per_person  \
# 1    10.34  1.66   Male     No  Sun  Dinner     3              3.45
# 2    21.01  3.50   Male     No  Sun  Dinner     3              7.00
# 3    23.68  3.31   Male     No  Sun  Dinner     2             11.84
# 5    25.29  4.71   Male     No  Sun  Dinner     4              6.32
# 6     8.77  2.00   Male     No  Sun  Dinner     2              4.38
# ..     ...   ...    ...    ...  ...     ...   ...               ...
# 236  12.60  1.00   Male    Yes  Sat  Dinner     2              6.30
# 237  32.83  1.17   Male    Yes  Sat  Dinner     2             16.42
# 239  29.03  5.92   Male     No  Sat  Dinner     3              9.68
# 241  22.67  2.00   Male    Yes  Sat  Dinner     2             11.34
# 242  17.82  1.75   Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 5            Erik Smith   213140353657882    Sun9679
# 6    Kristopher Johnson  2223727524230344    Sun5985
# ..                  ...               ...        ...
# 236       Matthew Myers  3543676378973965    Sat5032
# 237        Thomas Brown  4284722681265508    Sat2929
# 239       Michael Avila  5296068606052842    Sat2657
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [157 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bill              244 non-null    float64
#  1   tip               244 non-null    float64
#  2   gender            244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
# Let us group the data based on smoker column
df.groupby("smoker").count()
# Out:
#         bill  tip  gender  day  time  size  price_per_person  Payer Name  \
# smoker
# No       151  151     151  151   151   151               151         151
# Yes       93   93      93   93    93    93                93          93
#
#         CC Number  Payment ID
# smoker
# No            151         151
# Yes            93          93

# %%
g2=df.groupby("smoker")
g2.get_group("Yes")
# Out:
#       bill   tip  gender smoker  day    time  size  price_per_person  \
# 56   38.01  3.00    Male    Yes  Sat  Dinner     4              9.50
# 58   11.24  1.76    Male    Yes  Sat  Dinner     2              5.62
# 60   20.29  3.21    Male    Yes  Sat  Dinner     2             10.14
# 61   13.81  2.00    Male    Yes  Sat  Dinner     2              6.90
# 62   11.02  1.98    Male    Yes  Sat  Dinner     2              5.51
# ..     ...   ...     ...    ...  ...     ...   ...               ...
# 234  15.53  3.00    Male    Yes  Sat  Dinner     2              7.76
# 236  12.60  1.00    Male    Yes  Sat  Dinner     2              6.30
# 237  32.83  1.17    Male    Yes  Sat  Dinner     2             16.42
# 240  27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241  22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
#
#                 Payer Name         CC Number Payment ID
# 56   James Christensen DDS   349793629453226    Sat8903
# 58           Troy Guerrero  3560782621035582    Sat6683
# 60          Anthony Mclean   347614304015027    Sat2353
# 61          Ryan Hernandez     4766834726806    Sat3030
# 62             Joseph Hart   180046232326178    Sat2265
# ..                     ...               ...        ...
# 234          Tracy Douglas  4097938155941930    Sat7220
# 236          Matthew Myers  3543676378973965    Sat5032
# 237           Thomas Brown  4284722681265508    Sat2929
# 240         Monica Sanders  3506806155565404    Sat1766
# 241             Keith Wong  6011891618747196    Sat3880
#
# [93 rows x 11 columns]

# %%
g2.get_group("No")
# Out:
#       bill   tip  gender smoker   day    time  size  price_per_person  \
# 0    16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1    10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2    21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3    23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4    24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..     ...   ...     ...    ...   ...     ...   ...               ...
# 235  10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 238  35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239  29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 242  17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243  18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 4          Tonya Carter  4832732618637221    Sun2251
# ..                  ...               ...        ...
# 235       Sean Gonzalez  3534021246117605    Sat4615
# 238      Kimberly Crane      676184013727    Sat9777
# 239       Michael Avila  5296068606052842    Sat2657
# 242        Dennis Dixon     4375220550950      Sat17
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [151 rows x 11 columns]

# %%
df.groupby("day").count()
# Out:
#       bill  tip  gender  smoker  time  size  price_per_person  Payer Name  \
# day
# Fri     19   19      19      19    19    19                19          19
# Sat     87   87      87      87    87    87                87          87
# Sun     76   76      76      76    76    76                76          76
# Thur    62   62      62      62    62    62                62          62
#
#       CC Number  Payment ID
# day
# Fri          19          19
# Sat          87          87
# Sun          76          76
# Thur         62          62

# %%
df.groupby("smoker").count()
# Out:
#         bill  tip  gender  day  time  size
# smoker
# No       151  151     151  151   151   151
# Yes       93   93      93   93    93    93

# %%
df.groupby("time").count()
# Out:
#         total_bill  tip  sex  smoker  day  size  price_per_person  Payer Name  \
# time
# Dinner         176  176  176     176  176   176               176         176
# Lunch           68   68   68      68   68    68                68          68
#
#         CC Number  Payment ID
# time
# Dinner        176         176
# Lunch          68          68

# %%
# groupby multiple variables.
df.groupby(["gender","smoker"]).count()
# Out:
#                bill  tip  day  time  size  price_per_person  Payer Name  \
# gender smoker
# Female No        54   54   54    54    54                54          54
#        Yes       33   33   33    33    33                33          33
# Male   No        97   97   97    97    97                97          97
#        Yes       60   60   60    60    60                60          60
#
#                CC Number  Payment ID
# gender smoker
# Female No             54          54
#        Yes            33          33
# Male   No             97          97
#        Yes            60          60

# %%
df.groupby(["smoker","gender"]).count()
# Out:
#                bill  tip  day  time  size  price_per_person  Payer Name  \
# smoker gender
# No     Female    54   54   54    54    54                54          54
#        Male      97   97   97    97    97                97          97
# Yes    Female    33   33   33    33    33                33          33
#        Male      60   60   60    60    60                60          60
#
#                CC Number  Payment ID
# smoker gender
# No     Female         54          54
#        Male           97          97
# Yes    Female         33          33
#        Male           60          60

# %%
df.groupby(["gender","smoker","day"]).count()
# Out:
#                     bill  tip  time  size  price_per_person  Payer Name  \
# gender smoker day
# Female No     Fri      2    2     2     2                 2           2
#               Sat     13   13    13    13                13          13
#               Sun     14   14    14    14                14          14
#               Thur    25   25    25    25                25          25
#        Yes    Fri      7    7     7     7                 7           7
#               Sat     15   15    15    15                15          15
#               Sun      4    4     4     4                 4           4
#               Thur     7    7     7     7                 7           7
# Male   No     Fri      2    2     2     2                 2           2
#               Sat     32   32    32    32                32          32
#               Sun     43   43    43    43                43          43
#               Thur    20   20    20    20                20          20
#        Yes    Fri      8    8     8     8                 8           8
#               Sat     27   27    27    27                27          27
#               Sun     15   15    15    15                15          15
#               Thur    10   10    10    10                10          10
#
#                     CC Number  Payment ID
# gender smoker day
# Female No     Fri           2           2
#               Sat          13          13
#               Sun          14          14
#               Thur         25          25
#        Yes    Fri           7           7
#               Sat          15          15
#               Sun           4           4
#               Thur          7           7
# Male   No     Fri           2           2
#               Sat          32          32
#               Sun          43          43
#               Thur         20          20
#        Yes    Fri           8           8
#               Sat          27          27
#               Sun          15          15
#               Thur         10          10

# %%
g2=df.groupby(["gender","smoker","day"])

# %%
df.groupby(["gender","smoker","day","time"]).count()
# Out:
#                            bill  tip  size
# gender smoker day  time
# Female No     Fri  Dinner     1    1     1
#                    Lunch      1    1     1
#               Sat  Dinner    13   13    13
#               Sun  Dinner    14   14    14
#               Thur Dinner     1    1     1
#                    Lunch     24   24    24
#        Yes    Fri  Dinner     4    4     4
#                    Lunch      3    3     3
#               Sat  Dinner    15   15    15
#               Sun  Dinner     4    4     4
#               Thur Lunch      7    7     7
# Male   No     Fri  Dinner     2    2     2
#               Sat  Dinner    32   32    32
#               Sun  Dinner    43   43    43
#               Thur Lunch     20   20    20
#        Yes    Fri  Dinner     5    5     5
#                    Lunch      3    3     3
#               Sat  Dinner    27   27    27
#               Sun  Dinner    15   15    15
#               Thur Lunch     10   10    10

# %%
df.groupby("smoker").count()
# Out:
#         bill  tip  gender  day  time  size  price_per_person  Payer Name  \
# smoker
# No       151  151     151  151   151   151               151         151
# Yes       93   93      93   93    93    93                93          93
#
#         CC Number  Payment ID
# smoker
# No            151         151
# Yes            93          93

# %%
# Applying Statistical/Math Functions on a group
group= df.groupby('smoker').agg({'size': ['sum', 'count',"mean"]})
print(group)
# Out:
#        size
#         sum count      mean
# smoker
# No      403   151  2.668874
# Yes     224    93  2.408602

# %%
group= df.groupby('smoker').agg({'tip': ['sum', 'count',"mean","min","max"]})
print(group)
# Out:
#            tip
#            sum count      mean
# smoker
# No      451.77   151  2.991854
# Yes     279.81    93  3.008710

# %%
group= df.groupby('smoker').agg({'bill': ['sum', 'count',"mean"]})
print(group)
# Out:
#            bill
#             sum count       mean
# smoker
# No      2897.43   151  19.188278
# Yes     1930.34    93  20.756344

# %%
# generate summary of day column with respect to bill ---> [min,max,mean,sum]
group= df.groupby('day').agg({'bill': ['sum',"mean","min","max"]})
print(group)
# Out:
#          bill
#           sum       mean   min    max
# day
# Fri    325.88  17.151579  5.75  40.17
# Sat   1778.40  20.441379  3.07  50.81
# Sun   1627.16  21.410000  7.25  48.17
# Thur  1096.33  17.682742  7.51  43.11

# %%
# accessing nth row from a group
g=df.groupby("gender")
g.get_group("Male")
# Out:
#       bill   tip gender smoker  day    time  size  price_per_person  \
# 1    10.34  1.66   Male     No  Sun  Dinner     3              3.45
# 2    21.01  3.50   Male     No  Sun  Dinner     3              7.00
# 3    23.68  3.31   Male     No  Sun  Dinner     2             11.84
# 5    25.29  4.71   Male     No  Sun  Dinner     4              6.32
# 6     8.77  2.00   Male     No  Sun  Dinner     2              4.38
# ..     ...   ...    ...    ...  ...     ...   ...               ...
# 236  12.60  1.00   Male    Yes  Sat  Dinner     2              6.30
# 237  32.83  1.17   Male    Yes  Sat  Dinner     2             16.42
# 239  29.03  5.92   Male     No  Sat  Dinner     3              9.68
# 241  22.67  2.00   Male    Yes  Sat  Dinner     2             11.34
# 242  17.82  1.75   Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# 1        Douglas Tucker  4478071379779230    Sun4608
# 2        Travis Walters  6011812112971322    Sun4458
# 3      Nathaniel Harris  4676137647685994    Sun5260
# 5            Erik Smith   213140353657882    Sun9679
# 6    Kristopher Johnson  2223727524230344    Sun5985
# ..                  ...               ...        ...
# 236       Matthew Myers  3543676378973965    Sat5032
# 237        Thomas Brown  4284722681265508    Sat2929
# 239       Michael Avila  5296068606052842    Sat2657
# 241          Keith Wong  6011891618747196    Sat3880
# 242        Dennis Dixon     4375220550950      Sat17
#
# [157 rows x 11 columns]

# %%
g.get_group("Female")
# Out:
#       bill   tip  gender smoker   day    time  size  price_per_person  \
# 0    16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4    24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11   35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14   14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16   10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..     ...   ...     ...    ...   ...     ...   ...               ...
# 226  10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229  22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238  35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240  27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243  18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# 4          Tonya Carter  4832732618637221    Sun2251
# 11         Diane Macias  4577817359320969    Sun6686
# 14        Vanessa Jones    30016702287574    Sun3848
# 16     Elizabeth Foster  4240025044626033    Sun9715
# ..                  ...               ...        ...
# 226          Ruth Weiss  5268689490381635    Fri6359
# 229    Jennifer Russell     4793003293608    Sat3943
# 238      Kimberly Crane      676184013727    Sat9777
# 240      Monica Sanders  3506806155565404    Sat1766
# 243     Michelle Hardin  3511451626698139    Thur672
#
# [87 rows x 11 columns]

# %%
df.groupby("day").count()
# Out:
#       bill  tip  gender  smoker  time  size  price_per_person  Payer Name  \
# day
# Fri     19   19      19      19    19    19                19          19
# Sat     87   87      87      87    87    87                87          87
# Sun     76   76      76      76    76    76                76          76
# Thur    62   62      62      62    62    62                62          62
#
#       CC Number  Payment ID
# day
# Fri          19          19
# Sat          87          87
# Sun          76          76
# Thur         62          62

# %%
print(g.head())
# Out:
#      bill   tip  gender smoker  day    time  size  price_per_person  \
# 0   16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1   10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2   21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3   23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4   24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5   25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6    8.77  2.00    Male     No  Sun  Dinner     2              4.38
# 11  35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 14  14.83  3.02  Female     No  Sun  Dinner     2              7.42
# 16  10.33  1.67  Female     No  Sun  Dinner     3              3.44
#
#             Payer Name         CC Number Payment ID
# 0   Christy Cunningham  3560325168603410    Sun2959
# 1       Douglas Tucker  4478071379779230    Sun4608
# 2       Travis Walters  6011812112971322    Sun4458
# 3     Nathaniel Harris  4676137647685994    Sun5260
# 4         Tonya Carter  4832732618637221    Sun2251
# 5           Erik Smith   213140353657882    Sun9679
# 6   Kristopher Johnson  2223727524230344    Sun5985
# 11        Diane Macias  4577817359320969    Sun6686
# 14       Vanessa Jones    30016702287574    Sun3848
# 16    Elizabeth Foster  4240025044626033    Sun9715

# %%
g.nth(1)
# Out:
#     bill   tip  gender smoker  day    time  size  price_per_person  \
# 2  21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 4  24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#        Payer Name         CC Number Payment ID
# 2  Travis Walters  6011812112971322    Sun4458
# 4    Tonya Carter  4832732618637221    Sun2251

# %%
g.nth(2)
# Out:
#      bill   tip  gender smoker  day    time  size  price_per_person  \
# 3   23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 11  35.26  5.00  Female     No  Sun  Dinner     4              8.82
#
#           Payer Name         CC Number Payment ID
# 3   Nathaniel Harris  4676137647685994    Sun5260
# 11      Diane Macias  4577817359320969    Sun6686

# %% [markdown]
# # **Cross_Tab (Cross Tabulation):**

# %%
df.head()
# Out:
#     bill   tip  gender smoker  day    time  size  price_per_person  \
# 0  16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1  10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2  21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3  23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4  24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
pd.crosstab(df["gender"],df["smoker"])
# Out:
# smoker  No  Yes
# gender
# Female  54   33
# Male    97   60

# %%
pd.crosstab(df["gender"],df["smoker"],normalize=True)
# Out:
# smoker        No       Yes
# gender
# Female  0.221311  0.135246
# Male    0.397541  0.245902

# %%
pd.crosstab(df["gender"],df["day"])
# Out:
# day     Fri  Sat  Sun  Thur
# gender
# Female    9   28   18    32
# Male     10   59   58    30
