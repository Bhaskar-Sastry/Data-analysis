# %% [markdown]
# # Assignment Instructions
#
# `Hello Innominion,`
#
# - **Try to attempt all the questions in every possible way.**
# - **Some other topics are required to solve some questions. don't panic.**
# - **Those questions can be answered after the topics are taught.**
#
#
# - `Join Mentoring Session for the Support/Doubts Resolving with Our Technical Mentors (2.00 PM - 6.00 PM  Mon-Sat)`
#
# Happy Learning !!!

# %% [markdown]
# ## Basics of Python

# %% [markdown]
# > `Question:` Print your name

# %%
# CODE HERE
print("BHASKAR")
# Out:
# BHASKAR

# %% [markdown]
# > `Question:` What is a variable? Write a Few words about Variables. Create a Variable with an Example.

# %%
# WRITE HERE
A variable is a name used to store data in a program.
A Variable** is a name given to a memory location used to store data in a program, and its value can change during execution.
Variables make programs easier to understand and manage by allowing data to be stored, reused, and modified efficiently.

# %%
# Code Here
age= 23
print("age")
# Out:
# age

# %% [markdown]
# >`Question:` Assume that we execute the following assignment statements:
# width = 17
# height = 12.0
# delimiter = '.'
# For each of the following expressions, write the value of the expression and the type (of the value of
# the expression).
# 1. width/2
# 2. width/2.0
# 3. height/3
# 4. 1 + 2 * 5
# 5. delimiter * 5

# %%
# CODE HERE
width = 17        # int
height = 12.0    # float
delimiter = '.'  # str

# %% [raw]
# # Sample Outputs
# 1. width/2 = 8.5
# 2. width/2.0 = 8.5
# 3. height/3 = 4.0
# 4. 11
# 5. .....

# %% [markdown]
# > `Question:` Add two number by taking variable names as first and seccond

# %%
#CODE HERE
a=50
b=80
sum =a+b
print(sum)
# Out:
# 130

# %%
first = 100
second = 200

addition = first + second

print("first number is :", first)
print("second number is :", second)
print("Addition of two numbers are :", addition)
# Out:
# first number is : 100
# second number is : 200
# Addition of two numbers are : 300

# %% [markdown]
# > `Question:` Add your first name and second name

# %%
# CODE HERE
first_name = "YNVS BHASKARA"
second_name = "SASTRY"
Full_name =first_name + " " + second_name
print("My first name is :", first_name)
print("My second name is :",second_name)
print("My full name is :", Full_name)
# Out:
# My first name is : YNVS BHASKARA
# My second name is : SASTRY
# My full name is : YNVS BHASKARA SASTRY

# %%
first_name = "Sachin"
second_name = "Tendulkar"

full_name = first_name + " " + second_name

print("My first name is :", first_name)
print("My second name is :", second_name)
print("My full name is :", full_name)
# Out:
# My first name is : Sachin
# My second name is : Tendulkar
# My full name is : Sachin Tendulkar

# %% [markdown]
# > `Question:` print the datatypes of the following
# - 10,'10',True,10.5

# %%
# CODE HERE
print(type(10))
print(type('10'))
print(type(True))
print(type(10.5))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %%
# Out:
# 10 -  <class 'int'>
# '10' -  <class 'str'>
# True -  <class 'bool'>
# 10.5 -  <class 'float'>

# %% [markdown]
#  `Question:`
# > - num_int = 123
# > - num_str = "456"
# > - Add num_int and num_str
# - `hint: first need to convert num_str into integer`

# %%
# CODE HERE
num_int = 123
num_str = "456"

result = num_int+int(num_str)

print("Addition of 123 and  456 is :",result)
# Out:
# Addition of 123 and  456 is : 579

# %%
# Out:
# Addition of 123 and 456 is :  579

# %% [markdown]
# ### Advanced Questions

# %% [markdown]
# > `Question:` The volume of a sphere with radius r is  4/3πr3  . What is the volume of a sphere with radius 5?

# %%
# CODE HERE
import math

r=5
volume = (4/3) * math.pi * r**3
print("the volume of sphere is:", volume)
# Out:
# the volume of sphere is: 523.5987755982989

# %% [markdown]
# > `Question:` Suppose the cover price of a book is Rs.24.95, but bookstores get a 40% discount. Shipping costs Rs.3 for the first copy and 75 paise for each additional copy. What is the total wholesale cost for 60 copies?

# %%
# CODE HERE

# %% [markdown]
# # [Innomatics Research Labs](https:/innomatics.in/)
# [www.innomatics.in](https:/innomatics.in/)
